# %%
import autogen

# %%
from pathlib import Path
from autogen.agentchat.contrib.capabilities.transform_messages import TransformMessages
from autogen.agentchat.contrib.capabilities.transforms import MessageHistoryLimiter


from autogen import LLMConfig



import copy
import os

from pydantic import BaseModel, Field

from autogen import ConversableAgent, UpdateSystemMessage, UserProxyAgent
from autogen.agentchat import a_initiate_group_chat,initiate_group_chat,register_function
from autogen.agentchat.group import (
    AgentTarget,
    ContextVariables,
    ReplyResult,
    OnCondition,
    StringLLMCondition,
    TerminateTarget,
)
from autogen.agentchat.group.patterns import (
    DefaultPattern,
)


import os
import shutil
from typing import Annotated

from autogen import ConversableAgent, LLMConfig
from typing import Literal
from typing import Tuple, List
import os


from IPython.display import display,Markdown

# %%
from scirag import REPO_DIR

# %%
import autogen
# from autogen import AfterWorkOption, ConversableAgent, initiate_swarm_chat
from autogen.agents.experimental import DocAgent

llm_config = LLMConfig(
    api_type="openai",
    model="gpt-4.1-2025-04-14",
    # model="gpt-4o-2024-11-20",
    # model="gpt-4o-mini",  # fast & cheap, tweak as needed
    api_key=os.environ.get("OPENAI_API_KEY", ""),
    temperature=0.3,
    
)

# %%
# Create a document agent and ask them to ingest the document and answer the question
document_agent = DocAgent(llm_config=llm_config, collection_name="toast_report")
run_response = document_agent.run(
    message="could you ingest /Users/boris/CMBAgents/scirag/papers/1807.06209v4.pdf? What is the mid-point redshift of reionisation, according to the Planck 2018 TT, TE, EE+ lowE analysis, with 68%CL?",
    max_turns=1,
)
run_response.process()
# Out:
# INFO:autogen.agents.experimental.document_agent.chroma_query_engine:Using existing collection toast_report from the database.
# user (to DocAgent):
#
# could you ingest /Users/boris/CMBAgents/scirag/papers/1807.06209v4.pdf? What phenomena is primarily driving the acoustic oscillations of the CMB power spectrum?
#
# --------------------------------------------------------------------------------
# _User (to chat_manager):
#
# could you ingest /Users/boris/CMBAgents/scirag/papers/1807.06209v4.pdf? What phenomena is primarily driving the acoustic oscillations of the CMB power spectrum?
#
# --------------------------------------------------------------------------------
#
# Next speaker: DocumentTriageAgent
#
# DocumentTriageAgent (to chat_manager):
#
# {"ingestions":[{"path_or_url":"/Users/boris/CMBAgents/scirag/papers/1807.06209v4.pdf"}],"queries":[{"query_type":"RAG_QUERY","query":"What phenomena is primarily driving the acoustic oscillations of the CMB power spectrum?"}]}
#
# ...

# %%
# Create a document agent and ask them to ingest the document and answer the question
document_agent = DocAgent(llm_config=llm_config, collection_name="toast_report")
run_response = document_agent.run(
    message="could you ingest /Users/boris/CMBAgents/scirag/markdowns/1807.06209v4.md? Which measurements are used to construct the high-multipole likelihoods in the Planck 2018 analysis?",
    max_turns=1,
)
run_response.process()
# Out:
# INFO:autogen.agents.experimental.document_agent.chroma_query_engine:Using existing collection toast_report from the database.
# user (to DocAgent):
#
# could you ingest /Users/boris/CMBAgents/scirag/markdowns/1807.06209v4.md? Which measurements are used to construct the high-multipole likelihoods in the Planck 2018 analysis?
#
# --------------------------------------------------------------------------------
# _User (to chat_manager):
#
# could you ingest /Users/boris/CMBAgents/scirag/markdowns/1807.06209v4.md? Which measurements are used to construct the high-multipole likelihoods in the Planck 2018 analysis?
#
# --------------------------------------------------------------------------------
#
# Next speaker: DocumentTriageAgent
#
# DocumentTriageAgent (to chat_manager):
#
# ...

# %%
# Create a document agent and ask them to ingest the document and answer the question
# document_agent = DocAgent(llm_config=llm_config, collection_name="toast_report")
# document_agent = DocAgent(llm_config=llm_config, collection_name="toast_report")
document_agent.reset()
run_response = document_agent.run(
    message="could you ingest /Users/boris/CMBAgents/scirag/papers/1807.06209v4.pdf? What is the mid-point redshift of reionisation, according to the Planck 2018 TT, TE, EE+ lowE analysis, with 68%CL?",
    max_turns=1,
)
run_response.process()
# Out:
# user (to DocAgent):
#
# could you ingest /Users/boris/CMBAgents/scirag/papers/1807.06209v4.pdf? What is the mid-point redshift of reionisation, according to the Planck 2018 TT, TE, EE+ lowE analysis, with 68%CL?
#
# --------------------------------------------------------------------------------
# _User (to chat_manager):
#
# could you ingest /Users/boris/CMBAgents/scirag/papers/1807.06209v4.pdf? What is the mid-point redshift of reionisation, according to the Planck 2018 TT, TE, EE+ lowE analysis, with 68%CL?
#
# --------------------------------------------------------------------------------
#
# Next speaker: DocumentTriageAgent
